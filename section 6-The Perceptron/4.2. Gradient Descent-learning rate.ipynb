# %% [markdown]
# ## Gradient Descent

# %% [markdown]
# #### To show the line while it's moving

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use("TkAgg")

# %% [markdown]
# #### function-drawing the line

# %%
def draw_line(x, y):
    line = plt.plot(x, y)
    plt.pause(0.0001)
    line[0].remove()

# %% [markdown]
# #### function-sigmoid

# %%
def sigmoid(input):
    return 1 / (1 + np.exp(-input) )

# %% [markdown]
# #### Function-calculating the error

# %%
def calculate_error(line_parameters, points, label):
    m = points.shape[0] # // returns a tuple of our arrays dimension
    linear_combination = points * line_parameters
    p = sigmoid(linear_combination)
    # // the CE-error equation, y = label
    cross_entropy = -1 * (np.log(p).T * label + np.log(1 - p).T * (1 - label))
    # print("cross_entropy", cross_entropy.shape)
    ce_error = cross_entropy / m
    print("ce_error = ", ce_error)
    print("the cross entropy error is: ", ce_error[0][0] * 100, "%")
    return ce_error

# %% [markdown]
# ## Function- gradient descent

# %%
def gradient_descent(line_parameters, points, label, learning_rate, loops_number):
    m = points.shape[0]
    for i in range(loops_number):
        p = sigmoid(points * line_parameters)
        gradient_descent = (points.T * (p - label) ) * (1 / m) * learning_rate
        line_parameters = line_parameters - gradient_descent
        w1 = line_parameters.item(0)
        w2 = line_parameters.item(1)
        b = line_parameters.item(2)

        x1 = np.array([points[:, 0].min() - 2, points[:, 0].max() + 2] )
        x2 = -b/w2 - (w1 * x1)/w2

        draw_line(x1, x2)
        calculate_error(line_parameters, points, label)

# %% [markdown]
# #### Initial steps - making and plotting the points

# %%
number_of_points = 50

np.random.seed(3)

## bias
bias_every_point = np.ones(number_of_points)

## top region
random_x1_values = np.random.normal(10, 2, number_of_points)  # // points according to the horizontal axis
random_x2_values = np.random.normal(12, 2, number_of_points)  # // points according to the vertical axis
top_region_points = np.array([random_x1_values, random_x2_values, bias_every_point]).T

## bottom region
random_x1_values_2 = np.random.normal(5, 2, number_of_points)
random_x2_values_2 = np.random.normal(6, 2, number_of_points)
bottom_region_points = np.array([random_x1_values_2, random_x2_values_2, bias_every_point]).T

## all points
all_points = np.vstack((top_region_points, bottom_region_points))

## Line
line_parameters = np.matrix([np.zeros(3)]).T # // took the transpose ,so we can multiply it by all_points

# x1 = np.array([bottom_region_points[:, 0].min() - 2, top_region_points[:, 0].max() + 2] ) # // [:, 0] means horizontal
# x2 = -b/w2 - (w1 * x1)/w2
# // copied and pasted in the gradient function

## Label
y = np.array([np.zeros(number_of_points), np.ones(number_of_points)]).reshape(number_of_points * 2, 1)
# // we basically make the first 50 points zeros and the second 50 points ones
# print(y)

# %% [markdown]
# #### Display the points

# %%
_, axis = plt.subplots(figsize=(4, 4) )

axis.scatter(top_region_points[:, 0], top_region_points[:, 1], color='r')
axis.scatter(bottom_region_points[:, 0], bottom_region_points[:, 1], color='b')
# gradient_descent(line_parameters, all_points, y, learning_rate=0.06, loops_number=600)
# new_line_parameters, new_all_points, new_y = gradient_descent(line_parameters, all_points, y, 0.02, 2000)
gradient_descent(line_parameters, all_points, y, 0.06, 6000)

plt.show()
# Out:
# ce_error =  [[0.69721139]]
# the cross entropy error is:  [[69.72113945]] %
# ce_error =  [[0.66414379]]
# the cross entropy error is:  [[66.41437905]] %
# ce_error =  [[0.6648325]]
# the cross entropy error is:  [[66.48325014]] %
# ce_error =  [[0.6516413]]
# the cross entropy error is:  [[65.16413039]] %
# ce_error =  [[0.65114463]]
# the cross entropy error is:  [[65.11446317]] %
# ce_error =  [[0.64328689]]
# the cross entropy error is:  [[64.32868854]] %
# ce_error =  [[0.64224103]]
# the cross entropy error is:  [[64.22410318]] %
# ce_error =  [[0.6368375]]
# the cross entropy error is:  [[63.68375021]] %
# ce_error =  [[0.63551771]]
# the cross entropy error is:  [[63.5517712]] %
# ce_error =  [[0.63149558]]
# the cross entropy error is:  [[63.14955797]] %
# ce_error =  [[0.63004469]]
# the cross entropy error is:  [[63.00446856]] %
# ce_error =  [[0.62688883]]
# the cross entropy error is:  [[62.68888307]] %
# ce_error =  [[0.62538837]]
# the cross entropy error is:  [[62.53883715]] %
# ce_error =  [[0.62281193]]
# the cross entropy error is:  [[62.28119314]] %
# ce_error =  [[0.62131022]]
# the cross entropy error is:  [[62.13102166]] %
# ce_error =  [[0.6191372]]
# the cross entropy error is:  [[61.91372037]] %
# ce_error =  [[0.61766241]]
# the cross entropy error is:  [[61.76624112]] %
# ce_error =  [[0.61577756]]
# the cross entropy error is:  [[61.57775566]] %
# ce_error =  [[0.61434481]]
# the cross entropy error is:  [[61.4344814]] %
# ce_error =  [[0.61266921]]
# the cross entropy error is:  [[61.26692094]] %
# ce_error =  [[0.61128497]]
# the cross entropy error is:  [[61.12849695]] %
# ce_error =  [[0.609763]]
# the cross entropy error is:  [[60.97630012]] %
# ce_error =  [[0.60842804]]
# the cross entropy error is:  [[60.84280429]] %
# ce_error =  [[0.60701979]]
# the cross entropy error is:  [[60.70197884]] %
# ce_error =  [[0.6057314]]
# the cross entropy error is:  [[60.57313957]] %
# ce_error =  [[0.60440789]]
# the cross entropy error is:  [[60.44078872]] %
# ce_error =  [[0.60316145]]
# the cross entropy error is:  [[60.31614479]] %
# ce_error =  [[0.60190155]]
# the cross entropy error is:  [[60.19015535]] %
# ce_error =  [[0.6006917]]
# the cross entropy error is:  [[60.06916956]] %
# ce_error =  [[0.59947997]]
# the cross entropy error is:  [[59.94799742]] %
# ce_error =  [[0.59830132]]
# the cross entropy error is:  [[59.83013242]] %
# ce_error =  [[0.5971265]]
# the cross entropy error is:  [[59.71265018]] %
# ce_error =  [[0.59597414]]
# the cross entropy error is:  [[59.59741376]] %
# ce_error =  [[0.594828]]
# the cross entropy error is:  [[59.48280016]] %
# ce_error =  [[0.59369768]]
# the cross entropy error is:  [[59.36976771]] %
# ce_error =  [[0.59257426]]
# the cross entropy error is:  [[59.25742619]] %
# ce_error =  [[0.59146247]]
# the cross entropy error is:  [[59.1462471]] %
# ce_error =  [[0.59035745]]
# the cross entropy error is:  [[59.03574549]] %
# ce_error =  [[0.5892614]]
# the cross entropy error is:  [[58.92613967]] %
# ce_error =  [[0.58817165]]
# the cross entropy error is:  [[58.81716546]] %
# ce_error =  [[0.58708915]]
# the cross entropy error is:  [[58.70891458]] %
# ce_error =  [[0.58601242]]
# the cross entropy error is:  [[58.60124183]] %
# ce_error =  [[0.58494179]]
# the cross entropy error is:  [[58.49417867]] %
# ce_error =  [[0.58387644]]
# the cross entropy error is:  [[58.38764364]] %
# ce_error =  [[0.58281641]]
# the cross entropy error is:  [[58.28164147]] %
# ce_error =  [[0.58176125]]
# the cross entropy error is:  [[58.17612492]] %
# ce_error =  [[0.58071088]]
# the cross entropy error is:  [[58.07108816]] %
# ce_error =  [[0.57966502]]
# the cross entropy error is:  [[57.9665025]] %
# ce_error =  [[0.57862359]]
# the cross entropy error is:  [[57.86235892]] %
# ce_error =  [[0.57758639]]
# the cross entropy error is:  [[57.75863902]] %
# ce_error =  [[0.57655334]]
# the cross entropy error is:  [[57.65533368]] %
# ce_error =  [[0.5755243]]
# the cross entropy error is:  [[57.55243038]] %
# ce_error =  [[0.57449921]]
# the cross entropy error is:  [[57.44992098]] %
# ce_error =  [[0.57347796]]
# the cross entropy error is:  [[57.34779647]] %
# ce_error =  [[0.5724605]]
# the cross entropy error is:  [[57.24604994]] %
# ce_error =  [[0.57144675]]
# the cross entropy error is:  [[57.14467456]] %
# ce_error =  [[0.57043665]]
# the cross entropy error is:  [[57.04366458]] %
# ce_error =  [[0.56943015]]
# the cross entropy error is:  [[56.94301459]] %
# ce_error =  [[0.5684272]]
# the cross entropy error is:  [[56.84271979]] %
# ce_error =  [[0.56742776]]
# the cross entropy error is:  [[56.74277577]] %
# ce_error =  [[0.56643178]]
# the cross entropy error is:  [[56.64317848]] %
# ce_error =  [[0.56543924]]
# the cross entropy error is:  [[56.54392423]] %
# ce_error =  [[0.5644501]]
# the cross entropy error is:  [[56.44500956]] %
# ce_error =  [[0.56346431]]
# the cross entropy error is:  [[56.34643132]] %
# ce_error =  [[0.56248187]]
# the cross entropy error is:  [[56.24818652]] %
# ce_error =  [[0.56150272]]
# the cross entropy error is:  [[56.15027241]] %
# ce_error =  [[0.56052686]]
# the cross entropy error is:  [[56.05268636]] %
# ce_error =  [[0.55955426]]
# the cross entropy error is:  [[55.95542595]] %
# ce_error =  [[0.55858489]]
# the cross entropy error is:  [[55.85848885]] %
# ce_error =  [[0.55761873]]
# the cross entropy error is:  [[55.76187288]] %
# ce_error =  [[0.55665576]]
# the cross entropy error is:  [[55.66557596]] %
# ce_error =  [[0.55569596]]
# the cross entropy error is:  [[55.56959609]] %
# ce_error =  [[0.55473931]]
# the cross entropy error is:  [[55.47393139]] %
# ce_error =  [[0.5537858]]
# the cross entropy error is:  [[55.37858005]] %
# ce_error =  [[0.5528354]]
# the cross entropy error is:  [[55.2835403]] %
# ce_error =  [[0.5518881]]
# the cross entropy error is:  [[55.18881049]] %
# ce_error =  [[0.55094389]]
# the cross entropy error is:  [[55.09438899]] %
# ce_error =  [[0.55000274]]
# the cross entropy error is:  [[55.00027423]] %
# ce_error =  [[0.54906465]]
# the cross entropy error is:  [[54.9064647]] %
# ce_error =  [[0.54812959]]
# the cross entropy error is:  [[54.81295892]] %
# ce_error =  [[0.54719755]]
# the cross entropy error is:  [[54.71975547]] %
# ce_error =  [[0.54626853]]
# the cross entropy error is:  [[54.62685295]] %
# ce_error =  [[0.5453425]]
# the cross entropy error is:  [[54.53425]] %
# ce_error =  [[0.54441945]]
# the cross entropy error is:  [[54.44194529]] %
# ce_error =  [[0.54349938]]
# the cross entropy error is:  [[54.34993751]] %
# ce_error =  [[0.54258225]]
# the cross entropy error is:  [[54.25822538]] %
# ce_error =  [[0.54166808]]
# the cross entropy error is:  [[54.16680767]] %
# ce_error =  [[0.54075683]]
# the cross entropy error is:  [[54.07568313]] %
# ce_error =  [[0.53984851]]
# the cross entropy error is:  [[53.98485054]] %
# ce_error =  [[0.53894309]]
# the cross entropy error is:  [[53.89430873]] %
# ce_error =  [[0.53804057]]
# the cross entropy error is:  [[53.80405651]] %
# ce_error =  [[0.53714093]]
# the cross entropy error is:  [[53.71409272]] %
# ce_error =  [[0.53624416]]
# the cross entropy error is:  [[53.62441621]] %
# ce_error =  [[0.53535026]]
# the cross entropy error is:  [[53.53502585]] %
# ce_error =  [[0.53445921]]
# the cross entropy error is:  [[53.44592051]] %
# ce_error =  [[0.53357099]]
# the cross entropy error is:  [[53.3570991]] %
# ce_error =  [[0.5326856]]
# the cross entropy error is:  [[53.2685605]] %
# ce_error =  [[0.53180304]]
# the cross entropy error is:  [[53.18030362]] %
# ce_error =  [[0.53092327]]
# the cross entropy error is:  [[53.0923274]] %
# ce_error =  [[0.53004631]]
# the cross entropy error is:  [[53.00463075]] %
# ce_error =  [[0.52917213]]
# the cross entropy error is:  [[52.91721261]] %
# ce_error =  [[0.52830072]]
# the cross entropy error is:  [[52.83007192]] %
# ce_error =  [[0.52743208]]
# the cross entropy error is:  [[52.74320764]] %
# ce_error =  [[0.52656619]]
# the cross entropy error is:  [[52.65661873]] %
# ce_error =  [[0.52570304]]
# the cross entropy error is:  [[52.57030414]] %
# ce_error =  [[0.52484263]]
# the cross entropy error is:  [[52.48426284]] %
# ce_error =  [[0.52398494]]
# the cross entropy error is:  [[52.39849382]] %
# ce_error =  [[0.52312996]]
# the cross entropy error is:  [[52.31299605]] %
# ce_error =  [[0.52227769]]
# the cross entropy error is:  [[52.22776852]] %
# ce_error =  [[0.5214281]]
# the cross entropy error is:  [[52.14281022]] %
# ce_error =  [[0.5205812]]
# the cross entropy error is:  [[52.05812015]] %
# ce_error =  [[0.51973697]]
# the cross entropy error is:  [[51.97369731]] %
# ce_error =  [[0.51889541]]
# the cross entropy error is:  [[51.8895407]] %
# ce_error =  [[0.51805649]]
# the cross entropy error is:  [[51.80564933]] %
# ce_error =  [[0.51722022]]
# the cross entropy error is:  [[51.72202222]] %
# ce_error =  [[0.51638658]]
# the cross entropy error is:  [[51.63865839]] %
# ce_error =  [[0.51555557]]
# the cross entropy error is:  [[51.55555685]] %
# ce_error =  [[0.51472717]]
# the cross entropy error is:  [[51.47271663]] %
# ce_error =  [[0.51390137]]
# the cross entropy error is:  [[51.39013677]] %
# ce_error =  [[0.51307816]]
# the cross entropy error is:  [[51.30781629]] %
# ce_error =  [[0.51225754]]
# the cross entropy error is:  [[51.22575423]] %
# ce_error =  [[0.5114395]]
# the cross entropy error is:  [[51.14394963]] %
# ce_error =  [[0.51062402]]
# the cross entropy error is:  [[51.06240155]] %
# ce_error =  [[0.50981109]]
# the cross entropy error is:  [[50.98110901]] %
# ce_error =  [[0.50900071]]
# the cross entropy error is:  [[50.90007108]] %
# ce_error =  [[0.50819287]]
# the cross entropy error is:  [[50.81928681]] %
# ce_error =  [[0.50738755]]
# the cross entropy error is:  [[50.73875526]] %
# ce_error =  [[0.50658475]]
# the cross entropy error is:  [[50.65847548]] %
# ce_error =  [[0.50578447]]
# the cross entropy error is:  [[50.57844654]] %
# ce_error =  [[0.50498668]]
# the cross entropy error is:  [[50.49866751]] %
# ce_error =  [[0.50419137]]
# the cross entropy error is:  [[50.41913746]] %
# ce_error =  [[0.50339855]]
# the cross entropy error is:  [[50.33985547]] %
# ce_error =  [[0.50260821]]
# the cross entropy error is:  [[50.2608206]] %
# ce_error =  [[0.50182032]]
# the cross entropy error is:  [[50.18203194]] %
# ce_error =  [[0.50103489]]
# the cross entropy error is:  [[50.10348857]] %
# ce_error =  [[0.5002519]]
# the cross entropy error is:  [[50.02518959]] %
# ce_error =  [[0.49947134]]
# the cross entropy error is:  [[49.94713406]] %
# ce_error =  [[0.49869321]]
# the cross entropy error is:  [[49.8693211]] %
# ce_error =  [[0.4979175]]
# the cross entropy error is:  [[49.7917498]] %
# ce_error =  [[0.49714419]]
# the cross entropy error is:  [[49.71441925]] %
# ce_error =  [[0.49637329]]
# the cross entropy error is:  [[49.63732855]] %
# ce_error =  [[0.49560477]]
# the cross entropy error is:  [[49.56047681]] %
# ce_error =  [[0.49483863]]
# the cross entropy error is:  [[49.48386314]] %
# ce_error =  [[0.49407487]]
# the cross entropy error is:  [[49.40748664]] %
# ce_error =  [[0.49331346]]
# the cross entropy error is:  [[49.33134644]] %
# ce_error =  [[0.49255442]]
# the cross entropy error is:  [[49.25544165]] %
# ce_error =  [[0.49179771]]
# the cross entropy error is:  [[49.17977138]] %
# ce_error =  [[0.49104335]]
# the cross entropy error is:  [[49.10433476]] %
# ce_error =  [[0.49029131]]
# the cross entropy error is:  [[49.02913091]] %
# ce_error =  [[0.48954159]]
# the cross entropy error is:  [[48.95415897]] %
# ce_error =  [[0.48879418]]
# the cross entropy error is:  [[48.87941807]] %
# ce_error =  [[0.48804907]]
# the cross entropy error is:  [[48.80490733]] %
# ce_error =  [[0.48730626]]
# the cross entropy error is:  [[48.7306259]] %
# ce_error =  [[0.48656573]]
# the cross entropy error is:  [[48.65657292]] %
# ce_error =  [[0.48582748]]
# the cross entropy error is:  [[48.58274753]] %
# ce_error =  [[0.48509149]]
# the cross entropy error is:  [[48.50914887]] %
# ce_error =  [[0.48435776]]
# the cross entropy error is:  [[48.4357761]] %
# ce_error =  [[0.48362628]]
# the cross entropy error is:  [[48.36262837]] %
# ce_error =  [[0.48289705]]
# the cross entropy error is:  [[48.28970483]] %
# ce_error =  [[0.48217005]]
# the cross entropy error is:  [[48.21700464]] %
# ce_error =  [[0.48144527]]
# the cross entropy error is:  [[48.14452697]] %
# ce_error =  [[0.48072271]]
# the cross entropy error is:  [[48.07227097]] %
# ce_error =  [[0.48000236]]
# the cross entropy error is:  [[48.00023581]] %
# ce_error =  [[0.47928421]]
# the cross entropy error is:  [[47.92842067]] %
# ce_error =  [[0.47856825]]
# the cross entropy error is:  [[47.85682471]] %
# ce_error =  [[0.47785447]]
# the cross entropy error is:  [[47.78544712]] %
# ce_error =  [[0.47714287]]
# the cross entropy error is:  [[47.71428706]] %
# ce_error =  [[0.47643344]]
# the cross entropy error is:  [[47.64334372]] %
# ce_error =  [[0.47572616]]
# the cross entropy error is:  [[47.57261629]] %
# ce_error =  [[0.47502104]]
# the cross entropy error is:  [[47.50210396]] %
# ce_error =  [[0.47431806]]
# the cross entropy error is:  [[47.43180591]] %
# ce_error =  [[0.47361721]]
# the cross entropy error is:  [[47.36172133]] %
# ce_error =  [[0.47291849]]
# the cross entropy error is:  [[47.29184942]] %
# ce_error =  [[0.47222189]]
# the cross entropy error is:  [[47.22218939]] %
# ce_error =  [[0.4715274]]
# the cross entropy error is:  [[47.15274043]] %
# ce_error =  [[0.47083502]]
# the cross entropy error is:  [[47.08350175]] %
# ce_error =  [[0.47014473]]
# the cross entropy error is:  [[47.01447255]] %
# ce_error =  [[0.46945652]]
# the cross entropy error is:  [[46.94565205]] %
# ce_error =  [[0.46877039]]
# the cross entropy error is:  [[46.87703946]] %
# ce_error =  [[0.46808634]]
# the cross entropy error is:  [[46.80863399]] %
# ce_error =  [[0.46740435]]
# the cross entropy error is:  [[46.74043487]] %
# ce_error =  [[0.46672441]]
# the cross entropy error is:  [[46.67244131]] %
# ce_error =  [[0.46604653]]
# the cross entropy error is:  [[46.60465255]] %
# ce_error =  [[0.46537068]]
# the cross entropy error is:  [[46.5370678]] %
# ce_error =  [[0.46469686]]
# the cross entropy error is:  [[46.4696863]] %
# ce_error =  [[0.46402507]]
# the cross entropy error is:  [[46.40250728]] %
# ce_error =  [[0.4633553]]
# the cross entropy error is:  [[46.33552998]] %
# ce_error =  [[0.46268754]]
# the cross entropy error is:  [[46.26875364]] %
# ce_error =  [[0.46202178]]
# the cross entropy error is:  [[46.2021775]] %
# ce_error =  [[0.46135801]]
# the cross entropy error is:  [[46.1358008]] %
# ce_error =  [[0.46069623]]
# the cross entropy error is:  [[46.0696228]] %
# ce_error =  [[0.46003643]]
# the cross entropy error is:  [[46.00364273]] %
# ce_error =  [[0.4593786]]
# the cross entropy error is:  [[45.93785986]] %
# ce_error =  [[0.45872273]]
# the cross entropy error is:  [[45.87227343]] %
# ce_error =  [[0.45806883]]
# the cross entropy error is:  [[45.80688272]] %
# ce_error =  [[0.45741687]]
# the cross entropy error is:  [[45.74168698]] %
# ce_error =  [[0.45676685]]
# the cross entropy error is:  [[45.67668547]] %
# ce_error =  [[0.45611877]]
# the cross entropy error is:  [[45.61187746]] %
# ce_error =  [[0.45547262]]
# the cross entropy error is:  [[45.54726222]] %
# ce_error =  [[0.45482839]]
# the cross entropy error is:  [[45.48283903]] %
# ce_error =  [[0.45418607]]
# the cross entropy error is:  [[45.41860715]] %
# ce_error =  [[0.45354566]]
# the cross entropy error is:  [[45.35456587]] %
# ce_error =  [[0.45290714]]
# the cross entropy error is:  [[45.29071447]] %
# ce_error =  [[0.45227052]]
# the cross entropy error is:  [[45.22705223]] %
# ce_error =  [[0.45163578]]
# the cross entropy error is:  [[45.16357844]] %
# ce_error =  [[0.45100292]]
# the cross entropy error is:  [[45.10029238]] %
# ce_error =  [[0.45037193]]
# the cross entropy error is:  [[45.03719335]] %
# ce_error =  [[0.44974281]]
# the cross entropy error is:  [[44.97428064]] %
# ce_error =  [[0.44911554]]
# the cross entropy error is:  [[44.91155355]] %
# ce_error =  [[0.44849011]]
# the cross entropy error is:  [[44.84901138]] %
# ce_error =  [[0.44786653]]
# the cross entropy error is:  [[44.78665343]] %
# ce_error =  [[0.44724479]]
# the cross entropy error is:  [[44.72447901]] %
# ce_error =  [[0.44662487]]
# the cross entropy error is:  [[44.66248742]] %
# ce_error =  [[0.44600678]]
# the cross entropy error is:  [[44.60067798]] %
# ce_error =  [[0.4453905]]
# the cross entropy error is:  [[44.53905]] %
# ce_error =  [[0.44477603]]
# the cross entropy error is:  [[44.47760279]] %
# ce_error =  [[0.44416336]]
# the cross entropy error is:  [[44.41633567]] %
# ce_error =  [[0.44355248]]
# the cross entropy error is:  [[44.35524796]] %
# ce_error =  [[0.44294339]]
# the cross entropy error is:  [[44.294339]] %
# ce_error =  [[0.44233608]]
# the cross entropy error is:  [[44.2336081]] %
# ce_error =  [[0.44173055]]
# the cross entropy error is:  [[44.17305459]] %
# ce_error =  [[0.44112678]]
# the cross entropy error is:  [[44.11267781]] %
# ce_error =  [[0.44052477]]
# the cross entropy error is:  [[44.05247708]] %
# ce_error =  [[0.43992452]]
# the cross entropy error is:  [[43.99245176]] %
# ce_error =  [[0.43932601]]
# the cross entropy error is:  [[43.93260117]] %
# ce_error =  [[0.43872925]]
# the cross entropy error is:  [[43.87292465]] %
# ce_error =  [[0.43813422]]
# the cross entropy error is:  [[43.81342156]] %
# ce_error =  [[0.43754091]]
# the cross entropy error is:  [[43.75409124]] %
# ce_error =  [[0.43694933]]
# the cross entropy error is:  [[43.69493304]] %
# ce_error =  [[0.43635946]]
# the cross entropy error is:  [[43.63594632]] %
# ce_error =  [[0.4357713]]
# the cross entropy error is:  [[43.57713042]] %
# ce_error =  [[0.43518485]]
# the cross entropy error is:  [[43.5184847]] %
# ce_error =  [[0.43460009]]
# the cross entropy error is:  [[43.46000853]] %
# ce_error =  [[0.43401701]]
# the cross entropy error is:  [[43.40170127]] %
# ce_error =  [[0.43343562]]
# the cross entropy error is:  [[43.34356228]] %
# ce_error =  [[0.43285591]]
# the cross entropy error is:  [[43.28559093]] %
# ce_error =  [[0.43227787]]
# the cross entropy error is:  [[43.2277866]] %
# ce_error =  [[0.43170149]]
# the cross entropy error is:  [[43.17014864]] %
# ce_error =  [[0.43112676]]
# the cross entropy error is:  [[43.11267645]] %
# ce_error =  [[0.43055369]]
# the cross entropy error is:  [[43.05536939]] %
# ce_error =  [[0.42998227]]
# the cross entropy error is:  [[42.99822685]] %
# ce_error =  [[0.42941248]]
# the cross entropy error is:  [[42.94124821]] %
# ce_error =  [[0.42884433]]
# the cross entropy error is:  [[42.88443285]] %
# ce_error =  [[0.4282778]]
# the cross entropy error is:  [[42.82778017]] %
# ce_error =  [[0.4277129]]
# the cross entropy error is:  [[42.77128955]] %
# ce_error =  [[0.4271496]]
# the cross entropy error is:  [[42.71496038]] %
# ce_error =  [[0.42658792]]
# the cross entropy error is:  [[42.65879207]] %
# ce_error =  [[0.42602784]]
# the cross entropy error is:  [[42.602784]] %
# ce_error =  [[0.42546936]]
# the cross entropy error is:  [[42.54693557]] %
# ce_error =  [[0.42491246]]
# the cross entropy error is:  [[42.4912462]] %
# ce_error =  [[0.42435715]]
# the cross entropy error is:  [[42.43571528]] %
# ce_error =  [[0.42380342]]
# the cross entropy error is:  [[42.38034222]] %
# ce_error =  [[0.42325126]]
# the cross entropy error is:  [[42.32512643]] %
# ce_error =  [[0.42270067]]
# the cross entropy error is:  [[42.27006733]] %
# ce_error =  [[0.42215164]]
# the cross entropy error is:  [[42.21516432]] %
# ce_error =  [[0.42160417]]
# the cross entropy error is:  [[42.16041682]] %
# ce_error =  [[0.42105824]]
# the cross entropy error is:  [[42.10582426]] %
# ce_error =  [[0.42051386]]
# the cross entropy error is:  [[42.05138605]] %
# ce_error =  [[0.41997102]]
# the cross entropy error is:  [[41.99710161]] %
# ce_error =  [[0.4194297]]
# the cross entropy error is:  [[41.94297038]] %
# ce_error =  [[0.41888992]]
# the cross entropy error is:  [[41.88899178]] %
# ce_error =  [[0.41835165]]
# the cross entropy error is:  [[41.83516524]] %
# ce_error =  [[0.4178149]]
# the cross entropy error is:  [[41.78149019]] %
# ce_error =  [[0.41727966]]
# the cross entropy error is:  [[41.72796608]] %
# ce_error =  [[0.41674592]]
# the cross entropy error is:  [[41.67459233]] %
# ce_error =  [[0.41621368]]
# the cross entropy error is:  [[41.62136839]] %
# ce_error =  [[0.41568294]]
# the cross entropy error is:  [[41.5682937]] %
# ce_error =  [[0.41515368]]
# the cross entropy error is:  [[41.5153677]] %
# ce_error =  [[0.4146259]]
# the cross entropy error is:  [[41.46258984]] %
# ce_error =  [[0.4140996]]
# the cross entropy error is:  [[41.40995958]] %
# ce_error =  [[0.41357476]]
# the cross entropy error is:  [[41.35747635]] %
# ce_error =  [[0.4130514]]
# the cross entropy error is:  [[41.30513961]] %
# ce_error =  [[0.41252949]]
# the cross entropy error is:  [[41.25294883]] %
# ce_error =  [[0.41200903]]
# the cross entropy error is:  [[41.20090345]] %
# ce_error =  [[0.41149003]]
# the cross entropy error is:  [[41.14900294]] %
# ce_error =  [[0.41097247]]
# the cross entropy error is:  [[41.09724676]] %
# ce_error =  [[0.41045634]]
# the cross entropy error is:  [[41.04563438]] %
# ce_error =  [[0.40994165]]
# the cross entropy error is:  [[40.99416525]] %
# ce_error =  [[0.40942839]]
# the cross entropy error is:  [[40.94283886]] %
# ce_error =  [[0.40891655]]
# the cross entropy error is:  [[40.89165466]] %
# ce_error =  [[0.40840612]]
# the cross entropy error is:  [[40.84061215]] %
# ce_error =  [[0.40789711]]
# the cross entropy error is:  [[40.78971078]] %
# ce_error =  [[0.4073895]]
# the cross entropy error is:  [[40.73895003]] %
# ce_error =  [[0.40688329]]
# the cross entropy error is:  [[40.6883294]] %
# ce_error =  [[0.40637848]]
# the cross entropy error is:  [[40.63784835]] %
# ce_error =  [[0.40587506]]
# the cross entropy error is:  [[40.58750638]] %
# ce_error =  [[0.40537303]]
# the cross entropy error is:  [[40.53730296]] %
# ce_error =  [[0.40487238]]
# the cross entropy error is:  [[40.48723759]] %
# ce_error =  [[0.4043731]]
# the cross entropy error is:  [[40.43730976]] %
# ce_error =  [[0.40387519]]
# the cross entropy error is:  [[40.38751896]] %
# ce_error =  [[0.40337865]]
# the cross entropy error is:  [[40.33786468]] %
# ce_error =  [[0.40288346]]
# the cross entropy error is:  [[40.28834643]] %
# ce_error =  [[0.40238964]]
# the cross entropy error is:  [[40.2389637]] %
# ce_error =  [[0.40189716]]
# the cross entropy error is:  [[40.18971598]] %
# ce_error =  [[0.40140603]]
# the cross entropy error is:  [[40.14060279]] %
# ce_error =  [[0.40091624]]
# the cross entropy error is:  [[40.09162363]] %
# ce_error =  [[0.40042778]]
# the cross entropy error is:  [[40.042778]] %
# ce_error =  [[0.39994065]]
# the cross entropy error is:  [[39.99406542]] %
# ce_error =  [[0.39945485]]
# the cross entropy error is:  [[39.94548539]] %
# ce_error =  [[0.39897037]]
# the cross entropy error is:  [[39.89703743]] %
# ce_error =  [[0.39848721]]
# the cross entropy error is:  [[39.84872106]] %
# ce_error =  [[0.39800536]]
# the cross entropy error is:  [[39.80053579]] %
# ce_error =  [[0.39752481]]
# the cross entropy error is:  [[39.75248113]] %
# ce_error =  [[0.39704557]]
# the cross entropy error is:  [[39.70455662]] %
# ce_error =  [[0.39656762]]
# the cross entropy error is:  [[39.65676177]] %
# ce_error =  [[0.39609096]]
# the cross entropy error is:  [[39.60909611]] %
# ce_error =  [[0.39561559]]
# the cross entropy error is:  [[39.56155916]] %
# ce_error =  [[0.3951415]]
# the cross entropy error is:  [[39.51415046]] %
# ce_error =  [[0.3946687]]
# the cross entropy error is:  [[39.46686954]] %
# ce_error =  [[0.39419716]]
# the cross entropy error is:  [[39.41971592]] %
# ce_error =  [[0.39372689]]
# the cross entropy error is:  [[39.37268915]] %
# ce_error =  [[0.39325789]]
# the cross entropy error is:  [[39.32578876]] %
# ce_error =  [[0.39279014]]
# the cross entropy error is:  [[39.27901429]] %
# ce_error =  [[0.39232365]]
# the cross entropy error is:  [[39.23236528]] %
# ce_error =  [[0.39185841]]
# the cross entropy error is:  [[39.18584127]] %
# ce_error =  [[0.39139442]]
# the cross entropy error is:  [[39.1394418]] %
# ce_error =  [[0.39093166]]
# the cross entropy error is:  [[39.09316643]] %
# ce_error =  [[0.39047015]]
# the cross entropy error is:  [[39.0470147]] %
# ce_error =  [[0.39000986]]
# the cross entropy error is:  [[39.00098616]] %
# ce_error =  [[0.3895508]]
# the cross entropy error is:  [[38.95508037]] %
# ce_error =  [[0.38909297]]
# the cross entropy error is:  [[38.90929687]] %
# ce_error =  [[0.38863635]]
# the cross entropy error is:  [[38.86363522]] %
# ce_error =  [[0.38818095]]
# the cross entropy error is:  [[38.81809499]] %
# ce_error =  [[0.38772676]]
# the cross entropy error is:  [[38.77267572]] %
# ce_error =  [[0.38727377]]
# the cross entropy error is:  [[38.72737698]] %
# ce_error =  [[0.38682198]]
# the cross entropy error is:  [[38.68219834]] %
# ce_error =  [[0.38637139]]
# the cross entropy error is:  [[38.63713935]] %
# ce_error =  [[0.385922]]
# the cross entropy error is:  [[38.59219959]] %
# ce_error =  [[0.38547379]]
# the cross entropy error is:  [[38.54737863]] %
# ce_error =  [[0.38502676]]
# the cross entropy error is:  [[38.50267603]] %
# ce_error =  [[0.38458091]]
# the cross entropy error is:  [[38.45809136]] %
# ce_error =  [[0.38413624]]
# the cross entropy error is:  [[38.4136242]] %
# ce_error =  [[0.38369274]]
# the cross entropy error is:  [[38.36927413]] %
# ce_error =  [[0.38325041]]
# the cross entropy error is:  [[38.32504072]] %
# ce_error =  [[0.38280924]]
# the cross entropy error is:  [[38.28092355]] %
# ce_error =  [[0.38236922]]
# the cross entropy error is:  [[38.23692221]] %
# ce_error =  [[0.38193036]]
# the cross entropy error is:  [[38.19303627]] %
# ce_error =  [[0.38149265]]
# the cross entropy error is:  [[38.14926532]] %
# ce_error =  [[0.38105609]]
# the cross entropy error is:  [[38.10560894]] %
# ce_error =  [[0.38062067]]
# the cross entropy error is:  [[38.06206673]] %
# ce_error =  [[0.38018638]]
# the cross entropy error is:  [[38.01863828]] %
# ce_error =  [[0.37975323]]
# the cross entropy error is:  [[37.97532316]] %
# ce_error =  [[0.37932121]]
# the cross entropy error is:  [[37.93212099]] %
# ce_error =  [[0.37889031]]
# the cross entropy error is:  [[37.88903134]] %
# ce_error =  [[0.37846054]]
# the cross entropy error is:  [[37.84605383]] %
# ce_error =  [[0.37803188]]
# the cross entropy error is:  [[37.80318804]] %
# ce_error =  [[0.37760434]]
# the cross entropy error is:  [[37.76043358]] %
# ce_error =  [[0.3771779]]
# the cross entropy error is:  [[37.71779004]] %
# ce_error =  [[0.37675257]]
# the cross entropy error is:  [[37.67525704]] %
# ce_error =  [[0.37632834]]
# the cross entropy error is:  [[37.63283417]] %
# ce_error =  [[0.37590521]]
# the cross entropy error is:  [[37.59052104]] %
# ce_error =  [[0.37548317]]
# the cross entropy error is:  [[37.54831726]] %
# ce_error =  [[0.37506222]]
# the cross entropy error is:  [[37.50622245]] %
# ce_error =  [[0.37464236]]
# the cross entropy error is:  [[37.4642362]] %
# ce_error =  [[0.37422358]]
# the cross entropy error is:  [[37.42235813]] %
# ce_error =  [[0.37380588]]
# the cross entropy error is:  [[37.38058787]] %
# ce_error =  [[0.37338925]]
# the cross entropy error is:  [[37.33892501]] %
# ce_error =  [[0.37297369]]
# the cross entropy error is:  [[37.29736919]] %
# ce_error =  [[0.3725592]]
# the cross entropy error is:  [[37.25592002]] %
# ce_error =  [[0.37214577]]
# the cross entropy error is:  [[37.21457713]] %
# ce_error =  [[0.3717334]]
# the cross entropy error is:  [[37.17334012]] %
# ce_error =  [[0.37132209]]
# the cross entropy error is:  [[37.13220864]] %
# ce_error =  [[0.37091182]]
# the cross entropy error is:  [[37.0911823]] %
# ce_error =  [[0.37050261]]
# the cross entropy error is:  [[37.05026073]] %
# ce_error =  [[0.37009444]]
# the cross entropy error is:  [[37.00944356]] %
# ce_error =  [[0.3696873]]
# the cross entropy error is:  [[36.96873042]] %
# ce_error =  [[0.36928121]]
# the cross entropy error is:  [[36.92812094]] %
# ce_error =  [[0.36887615]]
# the cross entropy error is:  [[36.88761475]] %
# ce_error =  [[0.36847212]]
# the cross entropy error is:  [[36.8472115]] %
# ce_error =  [[0.36806911]]
# the cross entropy error is:  [[36.80691082]] %
# ce_error =  [[0.36766712]]
# the cross entropy error is:  [[36.76671233]] %
# ce_error =  [[0.36726616]]
# the cross entropy error is:  [[36.7266157]] %
# ce_error =  [[0.36686621]]
# the cross entropy error is:  [[36.68662054]] %
# ce_error =  [[0.36646727]]
# the cross entropy error is:  [[36.64672652]] %
# ce_error =  [[0.36606933]]
# the cross entropy error is:  [[36.60693326]] %
# ce_error =  [[0.3656724]]
# the cross entropy error is:  [[36.56724043]] %
# ce_error =  [[0.36527648]]
# the cross entropy error is:  [[36.52764765]] %
# ce_error =  [[0.36488155]]
# the cross entropy error is:  [[36.48815459]] %
# ce_error =  [[0.36448761]]
# the cross entropy error is:  [[36.44876088]] %
# ce_error =  [[0.36409466]]
# the cross entropy error is:  [[36.4094662]] %
# ce_error =  [[0.3637027]]
# the cross entropy error is:  [[36.37027017]] %
# ce_error =  [[0.36331172]]
# the cross entropy error is:  [[36.33117247]] %
# ce_error =  [[0.36292173]]
# the cross entropy error is:  [[36.29217274]] %
# ce_error =  [[0.36253271]]
# the cross entropy error is:  [[36.25327064]] %
# ce_error =  [[0.36214466]]
# the cross entropy error is:  [[36.21446583]] %
# ce_error =  [[0.36175758]]
# the cross entropy error is:  [[36.17575797]] %
# ce_error =  [[0.36137147]]
# the cross entropy error is:  [[36.13714673]] %
# ce_error =  [[0.36098632]]
# the cross entropy error is:  [[36.09863176]] %
# ce_error =  [[0.36060213]]
# the cross entropy error is:  [[36.06021273]] %
# ce_error =  [[0.36021889]]
# the cross entropy error is:  [[36.0218893]] %
# ce_error =  [[0.35983661]]
# the cross entropy error is:  [[35.98366114]] %
# ce_error =  [[0.35945528]]
# the cross entropy error is:  [[35.94552792]] %
# ce_error =  [[0.35907489]]
# the cross entropy error is:  [[35.90748931]] %
# ce_error =  [[0.35869545]]
# the cross entropy error is:  [[35.86954497]] %
# ce_error =  [[0.35831695]]
# the cross entropy error is:  [[35.83169459]] %
# ce_error =  [[0.35793938]]
# the cross entropy error is:  [[35.79393784]] %
# ce_error =  [[0.35756274]]
# the cross entropy error is:  [[35.75627439]] %
# ce_error =  [[0.35718704]]
# the cross entropy error is:  [[35.71870391]] %
# ce_error =  [[0.35681226]]
# the cross entropy error is:  [[35.68122609]] %
# ce_error =  [[0.35643841]]
# the cross entropy error is:  [[35.6438406]] %
# ce_error =  [[0.35606547]]
# the cross entropy error is:  [[35.60654712]] %
# ce_error =  [[0.35569345]]
# the cross entropy error is:  [[35.56934534]] %
# ce_error =  [[0.35532235]]
# the cross entropy error is:  [[35.53223494]] %
# ce_error =  [[0.35495216]]
# the cross entropy error is:  [[35.49521561]] %
# ce_error =  [[0.35458287]]
# the cross entropy error is:  [[35.45828702]] %
# ce_error =  [[0.35421449]]
# the cross entropy error is:  [[35.42144887]] %
# ce_error =  [[0.35384701]]
# the cross entropy error is:  [[35.38470084]] %
# ce_error =  [[0.35348043]]
# the cross entropy error is:  [[35.34804263]] %
# ce_error =  [[0.35311474]]
# the cross entropy error is:  [[35.31147392]] %
# ce_error =  [[0.35274994]]
# the cross entropy error is:  [[35.27499441]] %
# ce_error =  [[0.35238604]]
# the cross entropy error is:  [[35.23860378]] %
# ce_error =  [[0.35202302]]
# the cross entropy error is:  [[35.20230175]] %
# ce_error =  [[0.35166088]]
# the cross entropy error is:  [[35.16608799]] %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 7
#       4 axis.scatter(bottom_region_points[:, 0], bottom_region_points[:, 1], color='b')
#       5 # gradient_descent(line_parameters, all_points, y, learning_rate=0.06, loops_number=600)
#       6 # new_line_parameters, new_all_points, new_y = gradient_descent(line_parameters, all_points, y, 0.02, 2000)
# ----> 7 gradient_descent(line_parameters, all_points, y, 0.06, 6000)
#       9 plt.show()
#
# Cell In[5], line 14, in gradient_descent(line_parameters, points, label, learning_rate, loops_number)
#      11 x1 = np.array([points[:, 0].min() - 2, points[:, 0].max() + 2] )
#      12 x2 = -b/w2 - (w1 * x1)/w2
# ---> 14 draw_line(x1, x2)
#      15 calculate_error(line_parameters, points, label)
#
# Cell In[2], line 3, in draw_line(x, y)
#       1 def draw_line(x, y):
#       2     line = plt.plot(x, y)
# ----> 3     plt.pause(0.0001)
#       4     line[0].remove()
#
# File D:\coding projects\PyCharm projects\new projects\S-D-C-2\.venv\Lib\site-packages\matplotlib\pyplot.py:663, in pause(interval)
#     661         canvas.draw_idle()
#     662     show(block=False)
# --> 663     canvas.start_event_loop(interval)
#     664 else:
#     665     time.sleep(interval)
#
# File D:\coding projects\PyCharm projects\new projects\S-D-C-2\.venv\Lib\site-packages\matplotlib\backends\_backend_tk.py:426, in FigureCanvasTk.start_event_loop(self, timeout)
#     423     else:
#     424         self._event_loop_id = self._tkcanvas.after_idle(
#     425             self.stop_event_loop)
# --> 426 self._tkcanvas.mainloop()
#
# File C:\new downloaded programs\python\Lib\tkinter\__init__.py:1505, in Misc.mainloop(self, n)
#    1503 def mainloop(self, n=0):
#    1504     """Call the mainloop of Tk."""
# -> 1505     self.tk.mainloop(n)
#
# KeyboardInterrupt:
