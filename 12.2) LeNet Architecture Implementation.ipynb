# %% [markdown]
# ### <span style="color:orange">12.1 Preprocessing Images.</span>

# %% [markdown]
# #### <span style="color:orange">Importing the Libraries.</span>

# %%
## for google colab
# !pip install keras==3.0

# %%
import numpy as np
import matplotlib.pyplot as plt
# import matplotlib
# matplotlib.use("TkAgg")

from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.layers import Conv2D, MaxPooling2D

import random

## New
import pickle  # // to unpickle pickled files
import pandas as pd

# %% [markdown]
# #### <span style="color:orange">Loading/Opening the files</span>

# %%
np.random.seed(0)

with open('traffic-signs/train.p', 'rb') as file:
    train_data_file = pickle.load(file)

with open('traffic-signs/test.p', 'rb') as file:
    test_data_file = pickle.load(file)

with open("traffic-signs/valid.p", "rb") as file:
    validation_data_file = pickle.load(file)

print(type(train_data_file) )

## X_train, y_train, ...
train_images, train_labels = train_data_file["features"], train_data_file["labels"]
test_images, test_labels = test_data_file["features"], test_data_file["labels"]
validation_images, validation_labels = validation_data_file["features"],                                                                  validation_data_file["labels"]
# Out:
# <class 'dict'>

# %% [raw]
# #### Des:
#
# ## Line: with
# # // with is used whenever you wish to execute two operations as a pair and have a block of code in
# # /  between

# %% [markdown]
# #### <span style="color:orange">Dataset Parameters.</span>

# %%
print(train_images.shape)
print(test_images.shape)
print(validation_images.shape)
# Out:
# (34799, 32, 32, 3)
# (12630, 32, 32, 3)
# (4410, 32, 32, 3)

# %%
print(train_labels.shape)
# Out:
# (34799,)

# %% [raw]
# ####  Des:
#
# # // for the train images, we only have 34799 images which are 32x32 pixels and RGB (3D).
# # // same description for the rest with different values.

# %% [markdown]
# #### <span style="color:orange">assert method.</span>

# %%
assert (train_images.shape[0] == train_labels.shape[0] ),\
    "The number of images is not equal to the number of labels"
assert (validation_images.shape[0] == validation_labels.shape[0]), \
    "The number of images is not equal to the number of labels"
assert (test_images.shape[0] == test_labels.shape[0]),\
    "The number of images is not equal to the number of labels"

assert (train_images.shape[1:] == (32, 32, 3) ),\
    "The dimensions of the images are not 32 x 32 x 3"
assert (validation_images.shape[1:] == (32, 32, 3) ),\
    "The dimensions of the images are not 32 x 32 x 3"
assert (test_images.shape[1:] == (32, 32, 3) ),\
    "The dimensions of the images are not 32 x 32 x 3"

# %% [markdown]
# #### <span style="color:orange">Using Pandas Library to read the csv file.</span>

# %%
dataset = pd.read_csv('traffic-signs/signnames.csv')

print("Dataset = \n", dataset)
# Out:
# Dataset =
#      ClassId                                           SignName
# 0         0                               Speed limit (20km/h)
# 1         1                               Speed limit (30km/h)
# 2         2                               Speed limit (50km/h)
# 3         3                               Speed limit (60km/h)
# 4         4                               Speed limit (70km/h)
# 5         5                               Speed limit (80km/h)
# 6         6                        End of speed limit (80km/h)
# 7         7                              Speed limit (100km/h)
# 8         8                              Speed limit (120km/h)
# 9         9                                         No passing
# 10       10       No passing for vechiles over 3.5 metric tons
# 11       11              Right-of-way at the next intersection
# 12       12                                      Priority road
# 13       13                                              Yield
# 14       14                                               Stop
# 15       15                                        No vechiles
# 16       16           Vechiles over 3.5 metric tons prohibited
# 17       17                                           No entry
# 18       18                                    General caution
# 19       19                        Dangerous curve to the left
# 20       20                       Dangerous curve to the right
# 21       21                                       Double curve
# 22       22                                         Bumpy road
# 23       23                                      Slippery road
# 24       24                          Road narrows on the right
# 25       25                                          Road work
# 26       26                                    Traffic signals
# 27       27                                        Pedestrians
# 28       28                                  Children crossing
# 29       29                                  Bicycles crossing
# 30       30                                 Beware of ice/snow
# 31       31                              Wild animals crossing
# 32       32                End of all speed and passing limits
# 33       33                                   Turn right ahead
# 34       34                                    Turn left ahead
# 35       35                                         Ahead only
# 36       36                               Go straight or right
# 37       37                                Go straight or left
# 38       38                                         Keep right
# 39       39                                          Keep left
# 40       40                               Roundabout mandatory
# 41       41                                  End of no passing
# 42       42  End of no passing by vechiles over 3.5 metric ...

# %% [markdown]
# #### <span style="color:orange">Plotting Samples of the Traffic data (from (10.1) MNIST for clarification).</span>

# %%
number_of_samples = []
number_of_classes = 43
cols = 5

fig, axes = plt.subplots(nrows=number_of_classes, ncols=cols, figsize=(5, 50),
                         layout='constrained')
# // figsize is the size of each grid (subplot), first the width then the height\

# fig.subplots_adjust( left=None, bottom=None,  right=None, top=None, wspace=None, hspace=None)

fig.tight_layout()
# // this is used to automatically deal with overlapping and separates the figures/subplots better

for col in range(cols): # // each col of the 5
    for r_index, row_info in dataset.iterrows(): # // each row(class) of the 10
        image_selected = train_images[train_labels == r_index]

        axes[r_index][col].imshow(image_selected[random.randint(0, (len(image_selected) - 1) ), : , : ],
                          cmap=plt.get_cmap("gray") )
        axes[r_index][col].axis("off")

        if col == 2:
            axes[r_index][col].set_title(str(r_index) + "-" + row_info["SignName"])

            number_of_samples.append(len(image_selected) )
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13520\2515904116.py:11: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()

# %% [raw]
# #### Des:
#
# ### Line: dataset.iterrows()
#
# # // instead of iterating through range like MNIST, we're iterating through this dataset.iterrows()
#
# ## dataset.iterrows():
# # // This is a pandas property, this allows us to iterate through our dataframe rows as index and series pairs.
# [index, Series]
#
# # // index is like iterating through the rows like before, index corresponds to the Class ID as well.
# # // Series is a 1D labeled array which holds the relevant data for each row
# # / like in this dataset -> Class ID, SignName   ex: for index:0 , series = [0, Speed limit (20km/h) ]

# %% [markdown]
# #### <span style="color:orange">Bar plot to show the number of images each Class has.</span>

# %%
print(number_of_samples)
# Out:
# [180, 1980, 2010, 1260, 1770, 1650, 360, 1290, 1260, 1320, 1800, 1170, 1890, 1920, 690, 540, 360, 990, 1080, 180, 300, 270, 330, 450, 240, 1350, 540, 210, 480, 240, 390, 690, 210, 599, 360, 1080, 330, 180, 1860, 270, 300, 210, 210]

# %% [raw]
# #### Des:
#
# # // this shows the number of images belonging to each class.

# %%
plt.figure(figsize=(12, 4) )
plt.bar(range(0, number_of_classes), number_of_samples, color="turquoise", width=0.9)
plt.title('Distribution of the training dataset')
plt.xlabel('Class')
plt.ylabel('Number of images')

plt.show()

# %% [raw]
# #### Des:
#
# ### Line: plt.bar
# # // first arg is the x-coordinate (each class),
# # // 2nd arg is the y-coordinate (number of images per each class) or (number_of_samples array)
# # // width arg is the width of the bars.
#
# # //  Note: Here not every class has many datatsets which is more realistic.

# %% [markdown]
# #### <span style="color:orange">Preprocessing the images.</span>

# %% [markdown]
# **We will focus on a random photo then apply the same to the rest.**

# %%
import cv2

# %%
# random_image = cv2.imread(train_images[1000] )
# cv2.imshow("Random Image", random_image)
# cv2.waitKey(0)

# %% [markdown]
# **Error: Expected 'filename' to be a str or path-like object**
#
# **That's why we will use plt.imshow() instead**

# %%
plt.imshow(train_images[1000])
plt.axis('off')
print("Image shape:", train_images[1000].shape)
print("Label of the pic:" , train_labels[1000] )
# Out:
# Image shape: (32, 32, 3)
# Label of the pic: 36

# %% [markdown]
# ##### <span style="color:orange">1. grayscale</span>

# %%
def grayscale(img):
    img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    return img

# %% [raw]
# #### Des:
#
# # // This is used because lightning isn't important here, what's important is the features of the
# # /  images like the edges, the curves and the shapes inside of it, etc..
#
# # // The second reason is making the image grayscale means that the image is 1D instead of 3D.
# # // This is more efficient and requies much less computing.

# %%
random_image = grayscale(train_images[1000] )

plt.imshow(random_image, cmap=plt.get_cmap("gray") )
plt.axis('off')
print("Image shape:", random_image.shape)
# Out:
# Image shape: (32, 32)

# %% [markdown]
# ##### <span style="color:orange">2. Histogram Equalization</span>

# %% [raw]
# #### Des:
#
# ### Histogram Equalization
# # // Aims to standardize the lighting in all of our images.
# # // after applying it, all images would have a bright effect and would all look similar w.r.t.
# # /  Lighting.
# # // This also results in higher contrast within our image, which can help with feature extraction.

# %%
def histogram_equalize(img):
    cv2.equalizeHist(img)
    return img

# %% [raw]
# #### Des:
#
# # // Note: this function accepts only grayscaled images.

# %%
random_image = histogram_equalize(random_image)
plt.imshow(random_image, cmap=plt.get_cmap('gray'))
plt.axis('off')
print(random_image.shape)
# Out:
# (32, 32)

# %% [markdown]
# ##### <span style="color:orange">3. Normalization</span>

# %%
def preprocessing_image(img):
    img = grayscale(img)
    img = histogram_equalize(img)
    img = img / 255
    return img

# %%
train_images_preprocessed = np.array(list(map(preprocessing_image, train_images) ) )
validation_images_preprocessed = np.array(list(map(preprocessing_image, validation_images) ) )
test_images_preprocessed = np.array(list(map(preprocessing_image, test_images) ) )

# %% [raw]
# #### Des:
#
# ## map function:
# # // it will iterate through the entire array and for every element of the array, that it loops
# # /  through, it reurns a new element based on the function that's executed for each item in the
# # /  array.

# %%
random_index = random.randint(0, len(train_images) - 1)

random_image = plt.imshow(train_images[random_index] )
plt.axis('off')
# Out:
# (-0.5, 31.5, 31.5, -0.5)

# %%
random_image_preprocessed = plt.imshow(train_images_preprocessed[random_index] )
plt.axis('off')
print("train images preprocessed shape: ", train_images_preprocessed.shape)
# Out:
# train images preprocessed shape:  (34799, 32, 32)

# %% [markdown]
# ##### <span style="color:orange">4. Reshaping</span>

# %% [raw]
# #### Des:
#
# # // This is done to have the images in the suitable shape for the CONV layers.
# # // same amount of pixels (unlike DNN which needs it flattened to 1D), but with the
# # /  addition of 1.

# %%
train_images_preprocessed = train_images_preprocessed.reshape(34799, 32, 32, 1)
test_images_preprocessed = test_images_preprocessed.reshape(12630, 32, 32, 1)
validation_images_preprocessed = validation_images_preprocessed.reshape(4410, 32, 32, 1)

# %% [markdown]
# ##### <span style="color:orange">5. One Hot Encoding</span>

# %%
train_labels = to_categorical(train_labels, num_classes=43)
test_labels = to_categorical(test_labels, num_classes=43)
validation_labels = to_categorical(validation_labels, num_classes=43)

# %% [markdown]
# ___

# %% [markdown]
# ### <span style="color:orange">12.2 LeNet Architecture Implementation</span>

# %% [markdown]
# ##### <span style="color:orange">LeNet model Architecture and Compilation</span>

# %%
def leNet_model():
    model = Sequential()
    ## Conv layer
    model.add(Conv2D(input_shape=(32, 32, 1) , filters=30, kernel_size=(5, 5), strides=1,
                     activation="relu") )
    ## Pooling Layer
    model.add(MaxPooling2D(pool_size=(2, 2) ) )
    ## Conv layer
    model.add(Conv2D(filters=15, kernel_size=(3, 3), activation='relu') )
    ## Pooling layer
    model.add(MaxPooling2D(pool_size=(2, 2) ) )

    ## Flatten layer
    model.add(Flatten() )
    ## DNN layers/ hidden layers
    model.add(Dense(units=500, activation="relu") )
    ## Dropout layer
    model.add(Dropout(rate=0.5) )
    ## Output layer (classification)
    model.add(Dense(units=number_of_classes, activation="softmax") )


    ## Compilation
    model.compile(optimizer=Adam(learning_rate=0.01), loss='categorical_crossentropy',
                  metrics=['accuracy'] )

    return model

# %% [raw]
# #### Des: model layers
#
# ### Line: 1st Conv layer
# ## input_shape arg.: input shape of the pics.
#
# # // The result of this layer will be (28, 28, 30), that's because we didn't use padding so the
# # /  edges will be ignored (2 pixel values). We did this because, mostly all traffic signs are
# # /  centered and the edges of the pic has no relevant information for the signs.
# # // Parameters are in the N.B.
#
# ### Line: 1st Pooling layer
# # // will reduce the dimensions by half -> (14, 14, 30).
# # // will still have a depth of 30 since pooling doesn't affect the depth/the feature map/kernels.
#
# ### Line: 2nd Conv layer
# # // The result of this layer will be (12, 12, 15)
# # // parameters are in the N.B.
#
# ### Line: 2nd Pooling layer
# # // The result of this layer will be (6, 6, 15)
#
# ### Line: Flatten layer
# # // to flatten to 1D array to feed it to the NN.
# # // (6, 6, 15) -> 6*6*15 = 540. -> (1, 540) or (None, 540)  ** 1 row not 1 col

# %%
nn_model = leNet_model()

print(nn_model.summary() )
# Out:
# D:\coding projects\PyCharm projects\new projects\S-D-C-2\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape              ┃    Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 30)        │        780 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 30)        │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 12, 12, 15)        │      4,065 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 15)          │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ flatten (Flatten)               │ (None, 540)               │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dense (Dense)                   │ (None, 500)               │    270,500 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dropout (Dropout)               │ (None, 500)               │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dense_1 (Dense)                 │ (None, 43)                │     21,543 │
# └─────────────────────────────────┴───────────────────────────┴────────────┘
#  Total params: 296,888 (1.13 MB)
#  Trainable params: 296,888 (1.13 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ****All parameters are described in the NB**

# %% [markdown]
# ##### <span style="color:orange">Fitting the Model</span>

# %%
nn_model_fit = nn_model.fit(x=train_images_preprocessed, y=train_labels,
                                validation_data=(validation_images_preprocessed, validation_labels),
                                epochs=12, batch_size=400, verbose=True, shuffle=True)
# Out:
# Epoch 1/12
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.2357 - loss: 2.8922 - val_accuracy: 0.7542 - val_loss: 0.8392
# Epoch 2/12
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.7936 - loss: 0.6887 - val_accuracy: 0.8615 - val_loss: 0.5007
# Epoch 3/12
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.8880 - loss: 0.3770 - val_accuracy: 0.8705 - val_loss: 0.4316
# Epoch 4/12
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.9173 - loss: 0.2689 - val_accuracy: 0.8866 - val_loss: 0.3701
# Epoch 5/12
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9329 - loss: 0.2227 - val_accuracy: 0.8959 - val_loss: 0.3679
# Epoch 6/12
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9448 - loss: 0.1798 - val_accuracy: 0.9014 - val_loss: 0.3331
# Epoch 7/12
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.9559 - loss: 0.1461 - val_accuracy: 0.9098 - val_loss: 0.3149
# Epoch 8/12
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.9584 - loss: 0.1394 - val_accuracy: 0.9007 - val_loss: 0.3786
# Epoch 9/12
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.9594 - loss: 0.1308 - val_accuracy: 0.9168 - val_loss: 0.3021
# Epoch 10/12
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9649 - loss: 0.1111 - val_accuracy: 0.9116 - val_loss: 0.3473
# Epoch 11/12
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.9665 - loss: 0.1050 - val_accuracy: 0.9247 - val_loss: 0.2803
# Epoch 12/12
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.9688 - loss: 0.1023 - val_accuracy: 0.9392 - val_loss: 0.2502

# %% [markdown]
# ##### <span style="color:orange">Saving/Loading the model.</span>

# %%
from keras.models import load_model

# // creates a HDF5 file nn_model.save('my_model.h5')  # / the hdf5 is wrong(old way)

# // creates a keras file (new way of saving)
nn_model.save('12.2.CNN_model_traffic_signs.keras')

# // deletes the existing model
# del nn_model

# // returns a compiled model
nn_model = load_model('12.2.CNN_model_traffic_signs.keras')

# %% [markdown]
# #### <span style="color:orange">Plotting model info</span>

# %% [markdown]
# ##### <span style="color:orange">Accuracy plot</span>

# %%
plt.plot(nn_model_fit.history['accuracy'], label= "train accuracy", color="blue" )
plt.plot(nn_model_fit.history['val_accuracy'], label="val accuracy", color="green" )

plt.xlabel('epochs')
# plt.legend(['accuracy'] )
plt.legend()
plt.title('Accuracies')
plt.show()

# %% [markdown]
# ##### <span style="color:orange">Loss plot</span>

# %%
loss_plot = plt.plot(nn_model_fit.history['loss'], label = 'train loss', color = "red" )
val_loss_plot = plt.plot(nn_model_fit.history['val_loss'], label='val loss', color = "orange")

plt.xlabel('epochs')
# plt.legend(['loss'] )
plt.legend()
plt.title('Losses')
plt.show()

# %% [markdown]
# #### <span style="color:orange">Evaluating the Model</span>

# %%
nn_model_score = nn_model.evaluate(test_images_preprocessed, test_labels, verbose=0)

print("Test score: ", nn_model_score[0] * 100 , "%")
print("Test accuracy: ", nn_model_score[1] * 100 , "%")
# Out:
# Test score:  50.29388070106506 %
# Test accuracy:  91.7497992515564 %

# %% [raw]
# #### Des:
#
# # // This isn't good enough at all, in the next lecture we will fine tune our model to get a better
# # /  performance.

# %% [markdown]
# ___
